# %%
install.packages("mclogit")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(mclogit)
# Out:
# Loading required package: Matrix

# %% [markdown]
# #### link to using regular expressions to load files
# https://stackoverflow.com/questions/47189714/reading-multiple-csv-files-from-a-folder-with-r-using-regex

# %% [markdown]
# ### Workflow test on dummy data
#     - Read in multiple files with different timescales
#     - Perform mclogit
#     - Create csv file with betas in the format below

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1 - Load data from python

# %%
load <- function(time) {
    my_datal = list()
    for (t in seq_along(time)){
        my_files = list.files(pattern = paste('mfdf.*?t', toString(time[[t]]), '.csv', sep=''))
        my_filesl = lapply(my_files, read.csv)
        my_datal[[t]] = my_filesl
    }
    return(my_datal)
}

# %%
time = list(4)
my_datal = load(time)

# %%
my_files
# Out:
# [1] "mfdf_test_ind0df_t4.csv" "mfdf_test_ind1df_t4.csv"
# [3] "mfdf_test_ind2df_t4.csv" "mfdf_test_ind3df_t4.csv"
# [5] "mfdf_test_pop_t4.csv"

# %% [markdown]
# #### 2 - Perform conditional logistic regression

# %%
multiple_times = list()
output_dfs = list()

for (t in seq_along(my_datal)) {
    mclogit_output = list()
    for (i in seq_along(my_datal[[t]])) {
        clogit = coef(mclogit(cbind(my_datal[[t]][[i]]$label, my_datal[[t]][[i]]$frame) ~ feature0 + feature1, data=my_datal[[t]][[i]]))
        mclogit_output[[i]] = as.data.frame(clogit)
    }
    multiple_times[[t]] = mclogit_output
    t_df = cbind(multiple_times[[t]])
    output_dfs[[t]] = t_df   
}
# Out:
# Iteration 1 - Deviance = 17.47149
# Iteration 2 - Deviance = 17.39196
# Iteration 3 - Deviance = 17.39131
# Iteration 4 - Deviance = 17.39131
# converged
#
# Iteration 1 - Deviance = 20.05095
# Iteration 2 - Deviance = 20.04348
# Iteration 3 - Deviance = 20.04348
# Iteration 4 - Deviance = 20.04348
# converged
#
# Iteration 1 - Deviance = 19.80216
# Iteration 2 - Deviance = 19.78016
# Iteration 3 - Deviance = 19.78016
# Iteration 4 - Deviance = 19.78016
# converged
#
# Iteration 1 - Deviance = 15.26865
# Iteration 2 - Deviance = 14.94328
# Iteration 3 - Deviance = 14.93312
# Iteration 4 - Deviance = 14.93311
# Iteration 5 - Deviance = 14.93311
# converged
#
# Iteration 1 - Deviance = 78.64466
# Iteration 2 - Deviance = 78.58138
# Iteration 3 - Deviance = 78.58136
# Iteration 4 - Deviance = 78.58136
# converged

# %% [markdown]
# #### 3 - Create csv file

# %%
output_df = do.call(rbind, output_dfs)
df = data.frame(matrix(unlist(output_df), nrow=length(output_df), byrow=T), stringsAsFactors=FALSE)
write.table(df, file='/Users/taylorcarter/Desktop/mfdf_test_output.csv', row.names=FALSE, col.names=list('beta1', 'beta2'), sep=",")

# %%
output_df
# Out:
#      [,1]
# [1,] -0.1683163, -0.2576266
# [2,] -0.57280550, -0.02581237
# [3,] -0.71163352, 0.06215971
# [4,] -1.55722146, 0.01253735
# [5,] -0.64130944, -0.03153729

# %% [markdown]
# ### Actual Data

# %% [markdown]
# #### Direction change feature

# %%
time = list(30, 60, 90, 1800)
my_datal = list()
for (t in seq_along(time)){
    my_files = list.files(pattern = paste('dc_positions0.*?df_t', toString(time[[t]]), '.csv', sep=''))
    my_files = my_files[order(nchar(my_files), my_files)]
    my_filesl = lapply(my_files, read.csv)
    my_datal[[t]] = my_filesl
}

# %%
my_files
# Out:
#  [1] "dc_positions0_ind0df_t1800.csv"
#  [2] "dc_positions0_ind1df_t1800.csv"
#  [3] "dc_positions0_ind2df_t1800.csv"
#  [4] "dc_positions0_ind3df_t1800.csv"
#  [5] "dc_positions0_ind4df_t1800.csv"
#  [6] "dc_positions0_ind5df_t1800.csv"
#  [7] "dc_positions0_ind6df_t1800.csv"
#  [8] "dc_positions0_ind7df_t1800.csv"
#  [9] "dc_positions0_ind8df_t1800.csv"
# [10] "dc_positions0_ind9df_t1800.csv"
# [11] "dc_positions0_ind10df_t1800.csv"
# [12] "dc_positions0_ind11df_t1800.csv"
# [13] "dc_positions0_population_df_t1800.csv"

# %%
multiple_times = list()
output_dfs = list()

for (t in seq_along(my_datal)) {
    mclogit_output = list()
    for (i in seq_along(my_datal[[t]])) {
        print(t)
        print(i)
        clogit = coef(mclogit(cbind(my_datal[[t]][[i]]$label, my_datal[[t]][[i]]$frame) ~ feature, data=my_datal[[t]][[i]]))
        mclogit_output[[i]] = as.data.frame(clogit)
    }
    multiple_times[[t]] = mclogit_output
    t_df = cbind(multiple_times[[t]])
    output_dfs[[t]] = t_df   
}
# Out:
# [1] 1
# [1] 1
#
# Iteration 1 - Deviance = 2843.268
# Iteration 2 - Deviance = 2840.956
# Iteration 3 - Deviance = 2840.956
# Iteration 4 - Deviance = 2840.956
# converged
# [1] 1
# [1] 2
#
# Iteration 1 - Deviance = 1003.585
# Iteration 2 - Deviance = 1003.578
# Iteration 3 - Deviance = 1003.578
# converged
# [1] 1
# [1] 3
#
# Iteration 1 - Deviance = 766.6397
# Iteration 2 - Deviance = 766.6397
# converged
# [1] 1
# [1] 4
#
# Iteration 1 - Deviance = 2702.181
# Iteration 2 - Deviance = 2699.735
# Iteration 3 - Deviance = 2699.735
# Iteration 4 - Deviance = 2699.735
# converged
# [1] 1
# [1] 5
#
# Iteration 1 - Deviance = 1006.199
# Iteration 2 - Deviance = 1006.197
# Iteration 3 - Deviance = 1006.197
# converged
# [1] 1
# [1] 6
#
# Iteration 1 - Deviance = 2522.374
# Iteration 2 - Deviance = 2513.219
# Iteration 3 - Deviance = 2513.209
# Iteration 4 - Deviance = 2513.209
# converged
# [1] 1
# [1] 7
#
# Iteration 1 - Deviance = 561.0003
# Iteration 2 - Deviance = 558.9908
# Iteration 3 - Deviance = 558.9848
# Iteration 4 - Deviance = 558.9848
# converged
# [1] 1
# [1] 8
#
# Iteration 1 - Deviance = 945.652
# Iteration 2 - Deviance = 945.2765
# Iteration 3 - Deviance = 945.2764
# Iteration 4 - Deviance = 945.2764
# converged
# [1] 1
# [1] 9
#
# Iteration 1 - Deviance = 697.1424
# Iteration 2 - Deviance = 696.8672
# Iteration 3 - Deviance = 696.8671
# Iteration 4 - Deviance = 696.8671
# converged
# [1] 1
# [1] 10
#
# Iteration 1 - Deviance = 1641.121
# Iteration 2 - Deviance = 1639.557
# Iteration 3 - Deviance = 1639.557
# Iteration 4 - Deviance = 1639.557
# converged
# [1] 1
# [1] 11
#
# Iteration 1 - Deviance = 2071.265
# Iteration 2 - Deviance = 2057.154
# Iteration 3 - Deviance = 2057.072
# Iteration 4 - Deviance = 2057.072
# converged
# [1] 1
# [1] 12
#
# Iteration 1 - Deviance = 489.3961
# Iteration 2 - Deviance = 489.1854
# Iteration 3 - Deviance = 489.1853
# Iteration 4 - Deviance = 489.1853
# converged
# [1] 1
# [1] 13
#
# Iteration 1 - Deviance = 38.36941
# Iteration 2 - Deviance = 38.1397
# Iteration 3 - Deviance = 38.1397
# Iteration 4 - Deviance = 38.1397
# converged
# [1] 1
# [1] 14
#
# Iteration 1 - Deviance = 31.8504
# Iteration 2 - Deviance = 31.8504
# converged
# [1] 1
# [1] 15
#
# Iteration 1 - Deviance = 20.34324
# Iteration 2 - Deviance = 20.33832
# Iteration 3 - Deviance = 20.33832
# Iteration 4 - Deviance = 20.33832
# converged
# [1] 1
# [1] 16
#
# Iteration 1 - Deviance = 19867.76
# Iteration 2 - Deviance = 19867.76
# converged
# [1] 2
# [1] 1
#
# Iteration 1 - Deviance = 1413.058
# Iteration 2 - Deviance = 1411.879
# Iteration 3 - Deviance = 1411.879
# Iteration 4 - Deviance = 1411.879
# converged
# [1] 2
# [1] 2
#
# Iteration 1 - Deviance = 495.7896
# Iteration 2 - Deviance = 495.7211
# Iteration 3 - Deviance = 495.7211
# converged
# [1] 2
# [1] 3
#
# Iteration 1 - Deviance = 349.0439
# Iteration 2 - Deviance = 348.4614
# Iteration 3 - Deviance = 348.4599
# Iteration 4 - Deviance = 348.4599
# converged
# [1] 2
# [1] 4
#
# Iteration 1 - Deviance = 1328.48
# Iteration 2 - Deviance = 1326.638
# Iteration 3 - Deviance = 1326.637
# Iteration 4 - Deviance = 1326.637
# converged
# [1] 2
# [1] 5
#
# Iteration 1 - Deviance = 500.0164
# Iteration 2 - Deviance = 500.0163
# Iteration 3 - Deviance = 500.0163
# converged
# [1] 2
# [1] 6
#
# Iteration 1 - Deviance = 1238.826
# Iteration 2 - Deviance = 1233.546
# Iteration 3 - Deviance = 1233.538
# Iteration 4 - Deviance = 1233.538
# converged
# [1] 2
# [1] 7
#
# Iteration 1 - Deviance = 283.4421
# Iteration 2 - Deviance = 281.9879
# Iteration 3 - Deviance = 281.982
# Iteration 4 - Deviance = 281.982
# converged
# [1] 2
# [1] 8
#
# Iteration 1 - Deviance = 462.897
# Iteration 2 - Deviance = 462.4691
# Iteration 3 - Deviance = 462.4688
# Iteration 4 - Deviance = 462.4688
# converged
# [1] 2
# [1] 9
#
# Iteration 1 - Deviance = 344.2395
# Iteration 2 - Deviance = 342.7017
# Iteration 3 - Deviance = 342.6924
# Iteration 4 - Deviance = 342.6924
# converged
# [1] 2
# [1] 10
#
# Iteration 1 - Deviance = 810.829
# Iteration 2 - Deviance = 809.4065
# Iteration 3 - Deviance = 809.4065
# converged
# [1] 2
# [1] 11
#
# Iteration 1 - Deviance = 1045.398
# Iteration 2 - Deviance = 1037.717
# Iteration 3 - Deviance = 1037.669
# Iteration 4 - Deviance = 1037.669
# converged
# [1] 2
# [1] 12
#
# Iteration 1 - Deviance = 226.9256
# Iteration 2 - Deviance = 226.907
# Iteration 3 - Deviance = 226.907
# converged
# [1] 2
# [1] 13
#
# Iteration 1 - Deviance = 1.255274
# Iteration 2 - Deviance = 0.434096
# Iteration 3 - Deviance = 0.1583975
# Iteration 4 - Deviance = 0.05881448
# Iteration 5 - Deviance = 0.02196895
# Iteration 6 - Deviance = 0.008218565
# Iteration 7 - Deviance = 0.003073468
# Iteration 8 - Deviance = 0.001148025
# Iteration 9 - Deviance = 0.0004281736
# Iteration 10 - Deviance = 0.0001594397
# Iteration 11 - Deviance = 5.927899e-05
# Iteration 12 - Deviance = 2.200812e-05
# Iteration 13 - Deviance = 8.160329e-06
# Iteration 14 - Deviance = 3.022348e-06
# Iteration 15 - Deviance = 1.118307e-06
# Iteration 16 - Deviance = 4.134477e-07
# Iteration 17 - Deviance = 1.527492e-07
# Iteration 18 - Deviance = 5.640073e-08
# Iteration 19 - Deviance = 2.081514e-08
# Iteration 20 - Deviance = 7.678873e-09
# Iteration 21 - Deviance = 2.831836e-09
# Iteration 22 - Deviance = 1.044034e-09
# Iteration 23 - Deviance = 3.848204e-10
# converged
# [1] 2
# [1] 14
#
# Iteration 1 - Deviance = 12.54728
# Iteration 2 - Deviance = 12.46262
# Iteration 3 - Deviance = 12.46247
# Iteration 4 - Deviance = 12.46247
# converged
# [1] 2
# [1] 15
#
# Iteration 1 - Deviance = 10.65977
# Iteration 2 - Deviance = 10.64921
# Iteration 3 - Deviance = 10.6492
# Iteration 4 - Deviance = 10.6492
# converged
# [1] 2
# [1] 16
#
# Iteration 1 - Deviance = 9918.824
# Iteration 2 - Deviance = 9918.824
# Iteration 3 - Deviance = 9918.824
# converged
# [1] 3
# [1] 1
#
# Iteration 1 - Deviance = 939.6222
# Iteration 2 - Deviance = 938.7186
# Iteration 3 - Deviance = 938.7185
# Iteration 4 - Deviance = 938.7185
# converged
# [1] 3
# [1] 2
#
# Iteration 1 - Deviance = 330.7655
# Iteration 2 - Deviance = 330.7281
# Iteration 3 - Deviance = 330.7281
# converged
# [1] 3
# [1] 3
#
# Iteration 1 - Deviance = 214.4692
# Iteration 2 - Deviance = 212.0836
# Iteration 3 - Deviance = 212.0452
# Iteration 4 - Deviance = 212.0452
# Iteration 5 - Deviance = 212.0452
# converged
# [1] 3
# [1] 4
#
# Iteration 1 - Deviance = 899.1326
# Iteration 2 - Deviance = 898.1198
# Iteration 3 - Deviance = 898.1197
# Iteration 4 - Deviance = 898.1197
# converged
# [1] 3
# [1] 5
#
# Iteration 1 - Deviance = 329.534
# Iteration 2 - Deviance = 329.5297
# Iteration 3 - Deviance = 329.5297
# converged
# [1] 3
# [1] 6
#
# Iteration 1 - Deviance = 804.1436
# Iteration 2 - Deviance = 799.8513
# Iteration 3 - Deviance = 799.8433
# Iteration 4 - Deviance = 799.8433
# converged
# [1] 3
# [1] 7
#
# Iteration 1 - Deviance = 192.5123
# Iteration 2 - Deviance = 192.1553
# Iteration 3 - Deviance = 192.1548
# Iteration 4 - Deviance = 192.1548
# converged
# [1] 3
# [1] 8
#
# Iteration 1 - Deviance = 305.8499
# Iteration 2 - Deviance = 305.6307
# Iteration 3 - Deviance = 305.6305
# Iteration 4 - Deviance = 305.6305
# converged
# [1] 3
# [1] 9
#
# Iteration 1 - Deviance = 218.9267
# Iteration 2 - Deviance = 218.8616
# Iteration 3 - Deviance = 218.8615
# Iteration 4 - Deviance = 218.8615
# converged
# [1] 3
# [1] 10
#
# Iteration 1 - Deviance = 543.605
# Iteration 2 - Deviance = 542.7777
# Iteration 3 - Deviance = 542.7777
# Iteration 4 - Deviance = 542.7777
# converged
# [1] 3
# [1] 11
#
# Iteration 1 - Deviance = 713.5935
# Iteration 2 - Deviance = 709.0741
# Iteration 3 - Deviance = 709.0499
# Iteration 4 - Deviance = 709.0499
# converged
# [1] 3
# [1] 12
#
# Iteration 1 - Deviance = 157.9833
# Iteration 2 - Deviance = 157.9832
# Iteration 3 - Deviance = 157.9832
# converged
# [1] 3
# [1] 13
#
# Iteration 1 - Deviance = 0.915204
# Iteration 2 - Deviance = 0.3166922
# Iteration 3 - Deviance = 0.1167385
# Iteration 4 - Deviance = 0.04378613
# Iteration 5 - Deviance = 0.01648027
# Iteration 6 - Deviance = 0.006194236
# Iteration 7 - Deviance = 0.002321407
# Iteration 8 - Deviance = 0.0008673282
# Iteration 9 - Deviance = 0.000323173
# Iteration 10 - Deviance = 0.0001201487
# Iteration 11 - Deviance = 4.459018e-05
# Iteration 12 - Deviance = 1.652598e-05
# Iteration 13 - Deviance = 6.118372e-06
# Iteration 14 - Deviance = 2.263315e-06
# Iteration 15 - Deviance = 8.366945e-07
# Iteration 16 - Deviance = 3.091394e-07
# Iteration 17 - Deviance = 1.141683e-07
# Iteration 18 - Deviance = 4.214711e-08
# Iteration 19 - Deviance = 1.555402e-08
# Iteration 20 - Deviance = 5.738336e-09
# Iteration 21 - Deviance = 2.116466e-09
# Iteration 22 - Deviance = 7.804222e-10
# Iteration 23 - Deviance = 2.877067e-10
# converged
# [1] 3
# [1] 14
#
# Iteration 1 - Deviance = 10.32356
# Iteration 2 - Deviance = 10.32001
# Iteration 3 - Deviance = 10.32001
# Iteration 4 - Deviance = 10.32001
# converged
# [1] 3
# [1] 15
#
# Iteration 1 - Deviance = 6599.178
# Iteration 2 - Deviance = 6599.178
# Iteration 3 - Deviance = 6599.178
# converged
# [1] 4
# [1] 1
#
# Iteration 1 - Deviance = 34.72797
# Iteration 2 - Deviance = 34.61935
# Iteration 3 - Deviance = 34.6191
# Iteration 4 - Deviance = 34.6191
# converged
# [1] 4
# [1] 2
#
# Iteration 1 - Deviance = 13.67233
# Iteration 2 - Deviance = 13.67193
# Iteration 3 - Deviance = 13.67193
# converged
# [1] 4
# [1] 3
#
# Iteration 1 - Deviance = 4.776998
# Iteration 2 - Deviance = 4.180516
# Iteration 3 - Deviance = 4.016423
# Iteration 4 - Deviance = 3.990999
# Iteration 5 - Deviance = 3.990025
# Iteration 6 - Deviance = 3.990023
# Iteration 7 - Deviance = 3.990023
# converged
# [1] 4
# [1] 4
#
# Iteration 1 - Deviance = 34.67755
# Iteration 2 - Deviance = 34.34436
# Iteration 3 - Deviance = 34.34228
# Iteration 4 - Deviance = 34.34228
# converged
# [1] 4
# [1] 5
#
# Iteration 1 - Deviance = 14.01941
# Iteration 2 - Deviance = 13.98956
# Iteration 3 - Deviance = 13.98956
# Iteration 4 - Deviance = 13.98956
# converged
# [1] 4
# [1] 6
#
# Iteration 1 - Deviance = 38.62441
# Iteration 2 - Deviance = 38.50142
# Iteration 3 - Deviance = 38.50128
# Iteration 4 - Deviance = 38.50128
# converged
# [1] 4
# [1] 7
#
# Iteration 1 - Deviance = 4.304513
# Iteration 2 - Deviance = 4.084668
# Iteration 3 - Deviance = 4.060506
# Iteration 4 - Deviance = 4.059882
# Iteration 5 - Deviance = 4.059882
# Iteration 6 - Deviance = 4.059882
# converged
# [1] 4
# [1] 8
#
# Iteration 1 - Deviance = 1.913917
# Iteration 2 - Deviance = 0.7824505
# Iteration 3 - Deviance = 0.3035758
# Iteration 4 - Deviance = 0.1154008
# Iteration 5 - Deviance = 0.04357075
# Iteration 6 - Deviance = 0.0163481
# Iteration 7 - Deviance = 0.006096174
# Iteration 8 - Deviance = 0.002262059
# Iteration 9 - Deviance = 0.0008365047
# Iteration 10 - Deviance = 0.0003086692
# Iteration 11 - Deviance = 0.0001137506
# Iteration 12 - Deviance = 4.188757e-05
# Iteration 13 - Deviance = 1.541804e-05
# Iteration 14 - Deviance = 5.673715e-06
# Iteration 15 - Deviance = 2.087598e-06
# Iteration 16 - Deviance = 7.680565e-07
# Iteration 17 - Deviance = 2.825669e-07
# Iteration 18 - Deviance = 1.039535e-07
# Iteration 19 - Deviance = 3.824298e-08
# Iteration 20 - Deviance = 1.406893e-08
# Iteration 21 - Deviance = 5.175696e-09
# Iteration 22 - Deviance = 1.904037e-09
# Iteration 23 - Deviance = 7.004572e-10
# Iteration 24 - Deviance = 2.576837e-10
# converged
# [1] 4
# [1] 9
#
# Iteration 1 - Deviance = 3.709743
# Iteration 2 - Deviance = 3.325004
# Iteration 3 - Deviance = 3.175022
# Iteration 4 - Deviance = 3.112699
# Iteration 5 - Deviance = 3.095036
# Iteration 6 - Deviance = 3.093741
# Iteration 7 - Deviance = 3.093735
# Iteration 8 - Deviance = 3.093735
# converged
# [1] 4
# [1] 10
#
# Iteration 1 - Deviance = 20.26147
# Iteration 2 - Deviance = 20.21866
# Iteration 3 - Deviance = 20.21864
# Iteration 4 - Deviance = 20.21864
# converged
# [1] 4
# [1] 11
#
# Iteration 1 - Deviance = 20.51403
# Iteration 2 - Deviance = 18.86966
# Iteration 3 - Deviance = 18.7739
# Iteration 4 - Deviance = 18.77321
# Iteration 5 - Deviance = 18.77321
# converged
# [1] 4
# [1] 12
#
# Iteration 1 - Deviance = 0.6274973
# Iteration 2 - Deviance = 0.2204803
# Iteration 3 - Deviance = 0.08046639
# Iteration 4 - Deviance = 0.02974529
# Iteration 5 - Deviance = 0.01102641
# Iteration 6 - Deviance = 0.004083583
# Iteration 7 - Deviance = 0.001509606
# Iteration 8 - Deviance = 0.0005571632
# Iteration 9 - Deviance = 0.0002053935
# Iteration 10 - Deviance = 7.565674e-05
# Iteration 11 - Deviance = 2.78542e-05
# Iteration 12 - Deviance = 1.025178e-05
# Iteration 13 - Deviance = 3.772475e-06
# Iteration 14 - Deviance = 1.388047e-06
# Iteration 15 - Deviance = 5.106846e-07
# Iteration 16 - Deviance = 1.878814e-07
# Iteration 17 - Deviance = 6.912011e-08
# Iteration 18 - Deviance = 2.542839e-08
# Iteration 19 - Deviance = 9.354696e-09
# Iteration 20 - Deviance = 3.441426e-09
# Iteration 21 - Deviance = 1.266035e-09
# Iteration 22 - Deviance = 4.657497e-10
# converged
# [1] 4
# [1] 13
#
# Iteration 1 - Deviance = 295.7331
# Iteration 2 - Deviance = 295.7283
# Iteration 3 - Deviance = 295.7283
# converged

# %%
output_df = do.call(rbind, output_dfs)
df = data.frame(matrix(unlist(output_df), nrow=length(output_df), byrow=T), stringsAsFactors=FALSE)
write.table(df, file='/Users/taylorcarter/Desktop/dc_positions0_output.csv', row.names=FALSE, col.names='beta', sep=",")

# %% [markdown]
# #### Social density feature

# %%
time = list(30, 60, 90, 1800)
my_datal = list()
for (t in seq_along(time)){
    my_files = list.files(pattern = paste('sd_positions0.*?df_t', toString(time[[t]]), '.csv', sep=''))
    my_files = my_files[order(nchar(my_files), my_files)]
    my_filesl = lapply(my_files, read.csv)
    my_datal[[t]] = my_filesl
#     print(my_files)
}

# %%
my_files
# Out:
#  [1] "sd_positions0_ind0df_t1800.csv"
#  [2] "sd_positions0_ind1df_t1800.csv"
#  [3] "sd_positions0_ind2df_t1800.csv"
#  [4] "sd_positions0_ind3df_t1800.csv"
#  [5] "sd_positions0_ind4df_t1800.csv"
#  [6] "sd_positions0_ind5df_t1800.csv"
#  [7] "sd_positions0_ind6df_t1800.csv"
#  [8] "sd_positions0_ind7df_t1800.csv"
#  [9] "sd_positions0_ind8df_t1800.csv"
# [10] "sd_positions0_ind9df_t1800.csv"
# [11] "sd_positions0_ind10df_t1800.csv"
# [12] "sd_positions0_ind11df_t1800.csv"
# [13] "sd_positions0_population_df_t1800.csv"

# %%
multiple_times = list()
output_dfs = list()

for (t in seq_along(my_datal)) {
    mclogit_output = list()
    for (i in seq_along(my_datal[[t]])) {
        print(t)
        print(i)
        clogit = coef(mclogit(cbind(my_datal[[t]][[i]]$label, my_datal[[t]][[i]]$frame) ~ feature, data=my_datal[[t]][[i]]))
        mclogit_output[[i]] = as.data.frame(clogit)
    }
    multiple_times[[t]] = mclogit_output
    t_df = cbind(multiple_times[[t]])
    output_dfs[[t]] = t_df   
}
# Out:
# [1] 1
# [1] 1
#
# Iteration 1 - Deviance = 2959.84
# Iteration 2 - Deviance = 2959.834
# Iteration 3 - Deviance = 2959.834
# converged
# [1] 1
# [1] 2
#
# Iteration 1 - Deviance = 2959.966
# Iteration 2 - Deviance = 2959.963
# Iteration 3 - Deviance = 2959.963
# converged
# [1] 1
# [1] 3
#
# Iteration 1 - Deviance = 2949.598
# Iteration 2 - Deviance = 2949.429
# Iteration 3 - Deviance = 2949.429
# Iteration 4 - Deviance = 2949.429
# converged
# [1] 1
# [1] 4
#
# Iteration 1 - Deviance = 2954.526
# Iteration 2 - Deviance = 2954.415
# Iteration 3 - Deviance = 2954.415
# converged
# [1] 1
# [1] 5
#
# Iteration 1 - Deviance = 2959.98
# Iteration 2 - Deviance = 2959.98
# Iteration 3 - Deviance = 2959.98
# converged
# [1] 1
# [1] 6
#
# Iteration 1 - Deviance = 2953.868
# Iteration 2 - Deviance = 2953.776
# Iteration 3 - Deviance = 2953.776
# converged
# [1] 1
# [1] 7
#
# Iteration 1 - Deviance = 2958.724
# Iteration 2 - Deviance = 2958.505
# Iteration 3 - Deviance = 2958.505
# converged
# [1] 1
# [1] 8
#
# Iteration 1 - Deviance = 2959.394
# Iteration 2 - Deviance = 2959.365
# Iteration 3 - Deviance = 2959.365
# converged
# [1] 1
# [1] 9
#
# Iteration 1 - Deviance = 2958.844
# Iteration 2 - Deviance = 2958.822
# Iteration 3 - Deviance = 2958.822
# converged
# [1] 1
# [1] 10
#
# Iteration 1 - Deviance = 2956.624
# Iteration 2 - Deviance = 2956.557
# Iteration 3 - Deviance = 2956.557
# converged
# [1] 1
# [1] 11
#
# Iteration 1 - Deviance = 2945.486
# Iteration 2 - Deviance = 2945.332
# Iteration 3 - Deviance = 2945.332
# converged
# [1] 1
# [1] 12
#
# Iteration 1 - Deviance = 2952.706
# Iteration 2 - Deviance = 2952.607
# Iteration 3 - Deviance = 2952.607
# Iteration 4 - Deviance = 2952.607
# converged
# [1] 1
# [1] 13
# Warning message in mclogit(cbind(my_datal[[t]][[i]]$label, my_datal[[t]][[i]]$frame) ~ :
# “removing feature from model due to insufficient within-choice set variance”
# Error in mclogit(cbind(my_datal[[t]][[i]]$label, my_datal[[t]][[i]]$frame) ~ : No predictor variable remains in model
# Traceback:
#
# 1. coef(mclogit(cbind(my_datal[[t]][[i]]$label, my_datal[[t]][[i]]$frame) ~
#  .     feature, data = my_datal[[t]][[i]]))
# 2. mclogit(cbind(my_datal[[t]][[i]]$label, my_datal[[t]][[i]]$frame) ~
#  .     feature, data = my_datal[[t]][[i]])
# 3. stop("No predictor variable remains in model")

# %%
output_df = do.call(rbind, output_dfs)
df = data.frame(matrix(unlist(output_df), nrow=length(output_df), byrow=T), stringsAsFactors=FALSE)
write.table(df, file='/Users/taylorcarter/Desktop/sd_positions0_output.csv', row.names=FALSE, col.names='beta', sep=",")
